# %%
# import packages
import cv2
from matplotlib import pyplot as plt

# %%
def plt_imshow(title, image):
    # convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(True)
	plt.show()

# %%
image = cv2.imread("Dakota_Johnson.jpg")
# plt_imshow("Image", image)

# %%
plt_imshow("Dakota Johnson Image", image)

# %%
# draw a circle around my face, two filled in circles covering my
# eyes, and a rectangle over top of my mouth
cv2.circle(image, (100, 150), 90, (0, 0, 255), 2)
plt_imshow("Output", image)
# cv2.circle(image, (150, 164), 10, (0, 0, 255), -1)
# cv2.circle(image, (192, 174), 10, (0, 0, 255), -1)
# cv2.rectangle(image, (134, 200), (186, 218), (0, 0, 255), -1)

# %%
cv2.circle(image, (70, 134), 15, (0, 0, 255), -1)
plt_imshow("Output", image)

# %%
# cv2.circle(image, (70, 135), 15, (0, 0, 255), -1)
# plt_imshow("Output", image)

# %%
# cv2.circle(image, (130, 130), 15, (0, 0, 255), -1)
# plt_imshow("Output", image)

# %%
cv2.circle(image, (131, 132), 15, (0, 0, 255), -1)
plt_imshow("Output", image)

# %%
cv2.rectangle(image, (75, 207), (135, 180), (0, 0, 255), -1)
plt_imshow("Output", image)
